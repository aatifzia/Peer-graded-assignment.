# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __Aatif Zia__
#
# Aerospace Design Engineer.

# %% [markdown]
# *As an Aerspace Engineer i want to apply machine learning to control theories and design theories in Engineering to develop the most optimzed solution for aerospace problems, this is why i am interested in Data science.*

# %% [markdown]
# 1. Python
# 1. R
# 1. SQL
# 1. Java
# 1. Julia
# 1. Scala
# 1. C/C++
# 1. JavaScript
# 1. Go
# 1. Swift
# 1. Matlab
# 1. SAS

# %% [markdown]
# 1. TensorFlow
# 2. SciPy
# 3. NumPy
# 4. Pandas
# 5. Matplotlib
# 6. Keras
# 7. Scikit-learn
# 8. PyTorch
# 9. Scrapy
# 10. BeautifulSoup

# %% [markdown]
# __The basic arithmetic expression are as follows__
# |Expression Name|Sign|Discription            | Example|
# |:---------------:|:----:|:-----------------------:|:---:|
# |Addition       |   +  |Used to add two or more numbers|4+5 = 9|
# |Subraction|-|Used to subtract two or more numbers|3-8 = -5|
# |Multiplication|* or X| Used to multiply two or more numbers|3X5 = 15|
# |Devision| / |USed to devide numbers in equal parts| 10/2 = 5|

# %% [markdown]
# ### The code below will identify if the number is an odd or even number

# %%
num1 = int (input ("Enter Number: "))
num2 = int (input ("Enter Number: "))
print (num1+num2)
print (num1-num2)
print (num1*num2)
print (num1/num2)
# Out:
# Enter Number: 5
# Enter Number: 6
# 11
# -1
# 30
# 0.8333333333333334

# %%
min = int (input ("Enter Minutes: "))
print ("Hours = ", min/60)
# Out:
# Enter Minutes: 45
# Hours =  0.75

# %% [markdown]
# ### The Objectives of this Notebook are
# * To understand and practice the markdown editing tools
# * To practice basic code building using Jupyter Notebook
# * To complete the Peer graded assignement of the coursera/IBM-Data Scientist Profesional Certificate course.
